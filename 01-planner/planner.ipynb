# %% [markdown]
# # Automated Project: Planning, Estimation and Allocation

# %%
import warnings
warnings.filterwarnings('ignore')

from dotenv import load_dotenv
import os

# Specify the path to the .env file in the parent directory
from pathlib import Path
env_path = Path('..') / '.env'  # Navigate to the parent directory

# Load the .env file
load_dotenv(dotenv_path=env_path)

# Access the variables
OPEN_AI_KEY = os.getenv('OPEN_AI_KEY')
SERPER_API_KEY = os.getenv('SERPER_API_KEY')
OPENAI_MODEL_NAME = 'gpt-3.5' #'gpt-4o-mini'

import yaml
from crewai import Agent, Task, Crew

# %%
# Define file paths for YAML configurations
files = {
    'agents': 'config/agents.yaml',
    'tasks': 'config/tasks.yaml'
}

# Load configurations from YAML files
configs = {}
for config_type, file_path in files.items():
    with open(file_path, 'r') as file:
        configs[config_type] = yaml.safe_load(file)

# Assign loaded configurations to specific variables
agents_config = configs['agents']
tasks_config = configs['tasks']

# %%
from typing import List
from pydantic import BaseModel, Field

class TaskEstimate(BaseModel):
    task_name: str = Field(..., description="Name of the task")
    estimated_time_hours: float = Field(..., description="Estimated time to complete the task in hours")
    required_resources: List[str] = Field(..., description="List of resources required to complete the task")

class Milestone(BaseModel):
    milestone_name: str = Field(..., description="Name of the milestone")
    tasks: List[str] = Field(..., description="List of task IDs associated with this milestone")

class ProjectPlan(BaseModel):
    tasks: List[TaskEstimate] = Field(..., description="List of tasks with their estimates")
    milestones: List[Milestone] = Field(..., description="List of project milestones")

# %%
# Creating Agents
project_planning_agent = Agent(
  config=agents_config['project_planning_agent']
)

estimation_agent = Agent(
  config=agents_config['estimation_agent']
)

resource_allocation_agent = Agent(
  config=agents_config['resource_allocation_agent']
)

# Creating Tasks
task_breakdown = Task(
  config=tasks_config['task_breakdown'],
  agent=project_planning_agent
)

time_resource_estimation = Task(
  config=tasks_config['time_resource_estimation'],
  agent=estimation_agent
)

resource_allocation = Task(
  config=tasks_config['resource_allocation'],
  agent=resource_allocation_agent,
  output_pydantic=ProjectPlan # This is the structured output we want
)

# Creating Crew
crew = Crew(
  agents=[
    project_planning_agent,
    estimation_agent,
    resource_allocation_agent
  ],
  tasks=[
    task_breakdown,
    time_resource_estimation,
    resource_allocation
  ],
  verbose=True
)
# Out:
# Overriding of current TracerProvider is not allowed

# %%
from IPython.display import display, Markdown

project = 'Website'
industry = 'Technology'
project_objectives = 'Create a website for a small business'
team_members = """
- John Doe (Project Manager)
- Jane Doe (Software Engineer)
- Bob Smith (Designer)
- Alice Johnson (QA Engineer)
- Tom Brown (QA Engineer)
"""
project_requirements = """
- Create a responsive design that works well on desktop and mobile devices
- Implement a modern, visually appealing user interface with a clean look
- Develop a user-friendly navigation system with intuitive menu structure
- Include an "About Us" page highlighting the company's history and values
- Design a "Services" page showcasing the business's offerings with descriptions
- Create a "Contact Us" page with a form and integrated map for communication
- Implement a blog section for sharing industry news and company updates
- Ensure fast loading times and optimize for search engines (SEO)
- Integrate social media links and sharing capabilities
- Include a testimonials section to showcase customer feedback and build trust
"""

# Format the dictionary as Markdown for a better display in Jupyter Lab
formatted_output = f"""
**Project Type:** {project}

**Project Objectives:** {project_objectives}

**Industry:** {industry}

**Team Members:**
{team_members}
**Project Requirements:**
{project_requirements}
"""
# Display the formatted output as Markdown
display(Markdown(formatted_output))
# Out:
# **Project Type:** Website
#
# **Project Objectives:** Create a website for a small business
#
# **Industry:** Technology
#
# **Team Members:**
#
# - John Doe (Project Manager)
# - Jane Doe (Software Engineer)
# - Bob Smith (Designer)
# - Alice Johnson (QA Engineer)
# - Tom Brown (QA Engineer)
#
# **Project Requirements:**
#
# - Create a responsive design that works well on desktop and mobile devices
# - Implement a modern, visually appealing user interface with a clean look
# - Develop a user-friendly navigation system with intuitive menu structure
# - Include an "About Us" page highlighting the company's history and values
# - Design a "Services" page showcasing the business's offerings with descriptions
# - Create a "Contact Us" page with a form and integrated map for communication
# - Implement a blog section for sharing industry news and company updates
# - Ensure fast loading times and optimize for search engines (SEO)
# - Integrate social media links and sharing capabilities
# - Include a testimonials section to showcase customer feedback and build trust

# %%
# The given Python dictionary
inputs = {
  'project_type': project,
  'project_objectives': project_objectives,
  'industry': industry,
  'team_members': team_members,
  'project_requirements': project_requirements
}

# Run the crew
result = crew.kickoff(
  inputs=inputs
)
# Out:
# # Agent: The Ultimate Project Planner
# ## Task: Carefully analyze the project_requirements for the Website project and break them down into individual tasks. Define each task's scope in detail, set achievable timelines, and ensure that all dependencies are accounted for:
#
# - Create a responsive design that works well on desktop and mobile devices
# - Implement a modern, visually appealing user interface with a clean look
# - Develop a user-friendly navigation system with intuitive menu structure
# - Include an "About Us" page highlighting the company's history and values
# - Design a "Services" page showcasing the business's offerings with descriptions
# - Create a "Contact Us" page with a form and integrated map for communication
# - Implement a blog section for sharing industry news and company updates
# - Ensure fast loading times and optimize for search engines (SEO)
# - Integrate social media links and sharing capabilities
# - Include a testimonials section to showcase customer feedback and build trust
#
#
# Team members:
#
# - John Doe (Project Manager)
# - Jane Doe (Software Engineer)
# - Bob Smith (Designer)
# - Alice Johnson (QA Engineer)
# - Tom Brown (QA Engineer)
#
#
#
#
# # Agent: The Ultimate Project Planner
# ## Final Answer:
# **Project Plan: Website Development for a Small Business**
#
# ---
#
# ### 1. Project Overview
#
# - **Goal**: Create a modern, responsive website for a small business that is visually appealing, user-friendly, and optimized for performance and search engines.
# - **Timeline**: 8 weeks
# - **Team Members**:
#   - John Doe (Project Manager)
#   - Jane Doe (Software Engineer)
#   - Bob Smith (Designer)
#   - Alice Johnson (QA Engineer)
#   - Tom Brown (QA Engineer)
#
# ---
#
# ### 2. Comprehensive Task Breakdown
#
# | Task ID | Task Name                                      | Task Description                                                                                                                                                                         | Responsible   | Duration | Dependencies                  | Deliverable                    |
# |---------|------------------------------------------------|-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|---------------|----------|-------------------------------|--------------------------------|
# | 1       | Project Kickoff                               | Conduct initial project meeting to discuss goals, scope, and deliverables.                                                                                                           | John Doe      | 1 day    | None                          | Project Charter                |
# | 2       | Research & Requirement Gathering               | Conduct market research, analyze competitors' websites, and gather requirements from stakeholders.                                                                                   | John Doe      | 5 days   | Task 1                        | Requirements Document          |
# | 3       | Wireframing                                   | Create wireframes for all website pages, focusing on layout and functionality.                                                                                                        | Bob Smith     | 5 days   | Task 2                        | Wireframe Designs              |
# | 4       | Mockup Design                                  | Develop high-fidelity mockups based on wireframes that include branding, colors, and typography.                                                                                       | Bob Smith     | 5 days   | Task 3                        | Mockup Designs                 |
# | 5       | Design Approval                                | Present designs to stakeholders for feedback and approval.                                                                                                                            | John Doe      | 3 days   | Task 4                        | Approved Designs               |
# | 6       | Responsive Design Implementation                | Develop a responsive design that functions seamlessly on both desktop and mobile devices.                                                                                              | Jane Doe      | 10 days  | Task 5                        | Responsive Website Framework    |
# | 7       | User Interface Development                      | Implement a modern, visually appealing user interface according to the design specifications.                                                                                         | Jane Doe      | 10 days  | Task 6                        | UI Completed                   |
# | 8       | Navigation System Development                   | Create a user-friendly navigation system with an intuitive menu structure to enhance user experience.                                                                                   | Jane Doe      | 5 days   | Task 7                        | Navigation System              |
# | 9       | Content Creation                               | Write and gather textual content for "About Us", "Services", "Contact Us", and "Testimonials" pages.                                                                                 | John Doe      | 7 days   | Task 2                        | Content Document               |
# | 10      | About Us Page Development                      | Develop "About Us" page highlighting the company's history and values.                                                                                                               | Jane Doe      | 5 days   | Task 9                        | About Us Page                  |
# | 11      | Services Page Development                      | Create "Services" page that showcases the business offerings with descriptions.                                                                                                       | Jane Doe      | 5 days   | Task 9                        | Services Page                  |
# | 12      | Contact Us Page Development                    | Design "Contact Us" page with form and integrated map.                                                                                                                                 | Jane Doe      | 5 days   | Task 9                        | Contact Us Page                |
# | 13      | Blog Section Development                        | Implement a section for a blog to share industry news and company updates.                                                                                                            | Jane Doe      | 7 days   | Task 12                       | Blog Section                   |
# | 14      | SEO Optimization                               | Ensure fast loading times and implement basic SEO tactics to optimize the website for search engines.                                                                                  | Jane Doe      | 5 days   | Tasks 6, 7, 8, 10, 11, 12    | SEO Report                     |
# | 15      | Social Media Integration                       | Add links to social media accounts and ensure sharing capabilities are functioning correctly.                                                                                           | Jane Doe      | 3 days   | Task 14                       | Social Media Integration        |
# | 16      | Testimonials Section Development                | Implement a testimonials section to showcase customer feedback and build trust.                                                                                                        | Jane Doe      | 3 days   | Task 9                        | Testimonials Page              |
# | 17      | Quality Assurance Testing                      | Conduct QA testing of the website functionality, usability, and compatibility across devices.                                                                                          | Alice Johnson, Tom Brown | 7 days   | Tasks 8, 10, 11, 12, 13, 14, 15, 16 | QA Testing Report              |
# | 18      | Launch Website                                 | Final review and launch the website to the public.                                                                                                                                   | John Doe      | 2 days   | Task 17                       | Live Website                   |
# | 19      | Post Launch Support                           | Provide support for any arising issues and collect user feedback for future improvements.                                                                                              | Entire Team   | 14 days  | Task 18                       | Support Documentation          |
#
# ---
#
# ### 3. Gantt Chart Visualization
#
# Please reference the attachment below for a Gantt chart that visually represents the timeline of tasks, showing the start and end dates for each task as well as dependencies.
#
# **[Insert Gantt Chart Visualization Here]**  *(This is a placeholder; ensure you're using software that generates Gantt Charts to create and attach the visual representation.)*
#
# ---
#
# ### 4. Conclusion
#
# This comprehensive project plan outlines all necessary tasks to successfully create the small business website. Each task is strategically defined with clear objectives, responsible parties, timelines, and deliverables to ensure a streamlined development process. Regular check-ins and adjustments may be necessary to stay on track and adapt to any changes during project execution.
#
# By following this plan, we are poised to deliver an impactful online presence for the small business, ensuring that all requirements are met efficiently.
#
# ---
#
# This format and thoroughness will ensure clarity and maintain progress throughout the life cycle of the project.
#
#
# # Agent: Expert Estimation Analyst
# ## Task: Thoroughly evaluate each task in the Website project to estimate the time, resources, and effort required. Use historical data, task complexity, and available resources to provide a realistic estimation for each task.
#
#
#
# # Agent: Expert Estimation Analyst
# ## Final Answer:
# ### Detailed Estimation Report for Website Development Project
#
# ---
#
# #### 1. Project Overview
#
# - **Goal**: Develop a modern, responsive website for a small business that is visually appealing, user-friendly, and optimized for performance and search engines.
# - **Timeline**: 8 weeks
#
# #### 2. Task Breakdown and Estimations
#
# | Task ID | Task Name                                      | Task Description                                                                                                                                                                         | Responsible                    | Duration    | Resources Required                     | Effort (Man-Hours)  | Risks/Uncertainties                                   | Deliverable                    |
# |---------|------------------------------------------------|-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|--------------------------------|-------------|----------------------------------------|----------------------|-------------------------------------------------------|--------------------------------|
# | 1       | Project Kickoff                               | Conduct initial project meeting to discuss goals, scope, and deliverables.                                                                                                           | John Doe                       | 1 day       | 1 Project Manager                     | 4                    | Misalignment on goals could delay the project.       | Project Charter                |
# | 2       | Research & Requirement Gathering               | Conduct market research, analyze competitors' websites, and gather requirements from stakeholders.                                                                                   | John Doe                       | 5 days      | 1 Project Manager                     | 20                   | Stakeholder availability may affect gathering effort. | Requirements Document          |
# | 3       | Wireframing                                   | Create wireframes for all website pages, focusing on layout and functionality.                                                                                                        | Bob Smith                      | 5 days      | 1 Designer                            | 40                   | Design misalignment may require rework.              | Wireframe Designs              |
# | 4       | Mockup Design                                 | Develop high-fidelity mockups based on wireframes that include branding, colors, and typography.                                                                                       | Bob Smith                      | 5 days      | 1 Designer                            | 40                   | Feedback could delay further progress.                | Mockup Designs                 |
# | 5       | Design Approval                                | Present designs to stakeholders for feedback and approval.                                                                                                                            | John Doe                       | 3 days      | 1 Project Manager, 1 Designer        | 20                   | Delays in obtaining approvals may impact timelines.   | Approved Designs               |
# | 6       | Responsive Design Implementation                | Develop a responsive design that functions seamlessly on both desktop and mobile devices.                                                                                              | Jane Doe                       | 10 days     | 1 Software Engineer                   | 80                   | Complexity in responsive design may lead to rework.  | Responsive Website Framework    |
# | 7       | User Interface Development                      | Implement a modern, visually appealing user interface according to the design specifications.                                                                                         | Jane Doe                       | 10 days     | 1 Software Engineer                   | 80                   | UI issues may arise during implementation.           | UI Completed                   |
# | 8       | Navigation System Development                   | Create a user-friendly navigation system with an intuitive menu structure to enhance user experience.                                                                                   | Jane Doe                       | 5 days      | 1 Software Engineer                   | 40                   | Complicated navigation may lead to user confusion.    | Navigation System              |
# | 9       | Content Creation                               | Write and gather textual content for "About Us", "Services", "Contact Us", and "Testimonials" pages.                                                                                 | John Doe                       | 7 days      | 1 Project Manager                     | 28                   | Limited input from stakeholders may cause delays.    | Content Document               |
# | 10      | About Us Page Development                      | Develop "About Us" page highlighting the company's history and values.                                                                                                               | Jane Doe                       | 5 days      | 1 Software Engineer                   | 40                   | Content acceptance may delay development.              | About Us Page                  |
# | 11      | Services Page Development                      | Create "Services" page that showcases the business offerings with descriptions.                                                                                                       | Jane Doe                       | 5 days      | 1 Software Engineer                   | 40                   | Content revisions could affect timeline.              | Services Page                  |
# | 12      | Contact Us Page Development                    | Design "Contact Us" page with form and integrated map.                                                                                                                                 | Jane Doe                       | 5 days      | 1 Software Engineer                   | 40                   | Integration difficulties could arise.                  | Contact Us Page                |
# | 13      | Blog Section Development                        | Implement a section for a blog to share industry news and company updates.                                                                                                            | Jane Doe                       | 7 days      | 1 Software Engineer                   | 56                   | Approval of blog content may take time.               | Blog Section                   |
# | 14      | SEO Optimization                               | Ensure fast loading times and implement basic SEO tactics to optimize the website for search engines.                                                                                  | Jane Doe                       | 5 days      | 1 Software Engineer                   | 40                   | SEO requirements may evolve.                           | SEO Report                     |
# | 15      | Social Media Integration                       | Add links to social media accounts and ensure sharing capabilities are functioning correctly.                                                                                           | Jane Doe                       | 3 days      | 1 Software Engineer                   | 24                   | Social media APIs may pose integration challenges.    | Social Media Integration        |
# | 16      | Testimonials Section Development                | Implement a testimonials section to showcase customer feedback and build trust.                                                                                                        | Jane Doe                       | 3 days      | 1 Software Engineer                   | 24                   | Collecting testimonials may take longer than expected.| Testimonials Page              |
# | 17      | Quality Assurance Testing                      | Conduct QA testing of the website functionality, usability, and compatibility across devices.                                                                                          | Alice Johnson, Tom Brown       | 7 days      | 2 QA Engineers                        | 56                   | Identifying bugs may extend testing duration.         | QA Testing Report              |
# | 18      | Launch Website                                 | Final review and launch the website to the public.                                                                                                                                   | John Doe                       | 2 days      | 1 Project Manager                     | 16                   | Last-minute changes could affect launch date.         | Live Website                   |
# | 19      | Post Launch Support                           | Provide support for any arising issues and collect user feedback for future improvements.                                                                                              | Entire Team                    | 14 days     | Entire Team                          | 112                   | Ongoing support issues could emerge post-launch.      | Support Documentation          |
#
# ---
#
# #### 3. Summary of Risks and Uncertainties
#
# 1. **Stakeholder Availability**: Delays in feedback or decision-making could impact project duration.
# 2. **Design Misalignment**: Potential for more revisions if designs do not meet stakeholder expectations.
# 3. **Technical Challenges**: Issues with integration of responsive design or backend functionality may require additional time.
# 4. **Content Approval**: Delayed approvals on content from stakeholders could stall development.
# 5. **SEO Changes**: Evolving SEO best practices may require adaptations mid-project.
#
# #### 4. Conclusion
#
# This detailed estimation incorporates historical data and the complexity of each task, providing a comprehensive roadmap for the website development project. By adhering to this plan while considering the identified risks, we will ensure the project stays on track and within budget, delivering a successful online presence for the small business within the 8-week timeline.
#
# ---
#
# This thorough approach ensures clarity and alignment among the team, setting the stage for an efficient and effective website development process.
#
#
# # Agent: Resource Allocation Strategist
# ## Task: Strategically allocate tasks for the Website project to team members based on their skills, availability, and current workload. Ensure that each task is assigned to the most suitable team member and that the workload is evenly distributed.
#
# Team members:
#
# - John Doe (Project Manager)
# - Jane Doe (Software Engineer)
# - Bob Smith (Designer)
# - Alice Johnson (QA Engineer)
# - Tom Brown (QA Engineer)
#
#
#
#
# # Agent: Resource Allocation Strategist
# ## Final Answer:
# {
#   "tasks": [
#     {
#       "task_name": "Project Kickoff",
#       "estimated_time_hours": 4,
#       "required_resources": ["John Doe"]
#     },
#     {
#       "task_name": "Research & Requirement Gathering",
#       "estimated_time_hours": 20,
#       "required_resources": ["John Doe"]
#     },
#     {
#       "task_name": "Wireframing",
#       "estimated_time_hours": 40,
#       "required_resources": ["Bob Smith"]
#     },
#     {
#       "task_name": "Mockup Design",
#       "estimated_time_hours": 40,
#       "required_resources": ["Bob Smith"]
#     },
#     {
#       "task_name": "Design Approval",
#       "estimated_time_hours": 20,
#       "required_resources": ["John Doe", "Bob Smith"]
#     },
#     {
#       "task_name": "Responsive Design Implementation",
#       "estimated_time_hours": 80,
#       "required_resources": ["Jane Doe"]
#     },
#     {
#       "task_name": "User Interface Development",
#       "estimated_time_hours": 80,
#       "required_resources": ["Jane Doe"]
#     },
#     {
#       "task_name": "Navigation System Development",
#       "estimated_time_hours": 40,
#       "required_resources": ["Jane Doe"]
#     },
#     {
#       "task_name": "Content Creation",
#       "estimated_time_hours": 28,
#       "required_resources": ["John Doe"]
#     },
#     {
#       "task_name": "About Us Page Development",
#       "estimated_time_hours": 40,
#       "required_resources": ["Jane Doe"]
#     },
#     {
#       "task_name": "Services Page Development",
#       "estimated_time_hours": 40,
#       "required_resources": ["Jane Doe"]
#     },
#     {
#       "task_name": "Contact Us Page Development",
#       "estimated_time_hours": 40,
#       "required_resources": ["Jane Doe"]
#     },
#     {
#       "task_name": "Blog Section Development",
#       "estimated_time_hours": 56,
#       "required_resources": ["Jane Doe"]
#     },
#     {
#       "task_name": "SEO Optimization",
#       "estimated_time_hours": 40,
#       "required_resources": ["Jane Doe"]
#     },
#     {
#       "task_name": "Social Media Integration",
#       "estimated_time_hours": 24,
#       "required_resources": ["Jane Doe"]
#     },
#     {
#       "task_name": "Testimonials Section Development",
#       "estimated_time_hours": 24,
#       "required_resources": ["Jane Doe"]
#     },
#     {
#       "task_name": "Quality Assurance Testing",
#       "estimated_time_hours": 56,
#       "required_resources": ["Alice Johnson", "Tom Brown"]
#     },
#     {
#       "task_name": "Launch Website",
#       "estimated_time_hours": 16,
#       "required_resources": ["John Doe"]
#     },
#     {
#       "task_name": "Post Launch Support",
#       "estimated_time_hours": 112,
#       "required_resources": ["Entire Team"]
#     }
#   ],
#   "milestones": [
#     {
#       "milestone_name": "Initial Setup and Design Phase",
#       "tasks": [
#         "Project Kickoff",
#         "Research & Requirement Gathering",
#         "Wireframing",
#         "Mockup Design",
#         "Design Approval"
#       ]
#     },
#     {
#       "milestone_name": "Development Phase",
#       "tasks": [
#         "Responsive Design Implementation",
#         "User Interface Development",
#         "Navigation System Development",
#         "Content Creation",
#         "About Us Page Development",
#         "Services Page Development",
#         "Contact Us Page Development",
#         "Blog Section Development",
#         "SEO Optimization",
#         "Social Media Integration",
#         "Testimonials Section Development"
#       ]
#     },
#     {
#       "milestone_name": "Testing and Launch Phase",
#       "tasks": [
#         "Quality Assurance Testing",
#         "Launch Website"
#       ]
#     },
#     {
#       "milestone_name": "Support Phase",
#       "tasks": [
#         "Post Launch Support"
#       ]
#     }
#   ]
# }
#
# Summary: Each task has been allocated to team members based on their individual strengths and roles within the project. John Doe, being the Project Manager, is primarily responsible for project kickoff, stakeholder communication, and content organization, ensuring that the project remains aligned with business goals. Bob Smith has been assigned design-related tasks based on his expertise, while Jane Doe takes on the bulk of the development tasks, capitalizing on her strengths in software engineering. The QA Engineers, Alice Johnson and Tom Brown, are assigned quality assurance tasks to ensure website functionality. The allocation aims to balance workload effectively while maximizing the team's strengths, thus enhancing the chances for project success within the specified timeline.

# %%
import pandas as pd

costs = 0.150 * (crew.usage_metrics.prompt_tokens + crew.usage_metrics.completion_tokens) / 1_000_000
print(f"Total costs: ${costs:.4f}")

# Convert UsageMetrics instance to a DataFrame
df_usage_metrics = pd.DataFrame([crew.usage_metrics.dict()])
df_usage_metrics
# Out:
# Total costs: $0.0012
#    total_tokens  prompt_tokens  cached_prompt_tokens  completion_tokens  \
# 0          7699           3963                     0               3736
#
#    successful_requests
# 0                    3

# %%
result.pydantic.dict()
# Out:
# {'tasks': [{'task_name': 'Project Kickoff',
#    'estimated_time_hours': 4.0,
#    'required_resources': ['John Doe']},
#   {'task_name': 'Research & Requirement Gathering',
#    'estimated_time_hours': 20.0,
#    'required_resources': ['John Doe']},
#   {'task_name': 'Wireframing',
#    'estimated_time_hours': 40.0,
#    'required_resources': ['Bob Smith']},
#   {'task_name': 'Mockup Design',
#    'estimated_time_hours': 40.0,
#    'required_resources': ['Bob Smith']},
#   {'task_name': 'Design Approval',
#    'estimated_time_hours': 20.0,
#    'required_resources': ['John Doe', 'Bob Smith']},
#   {'task_name': 'Responsive Design Implementation',
#    'estimated_time_hours': 80.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': 'User Interface Development',
#    'estimated_time_hours': 80.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': 'Navigation System Development',
#    'estimated_time_hours': 40.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': 'Content Creation',
#    'estimated_time_hours': 28.0,
#    'required_resources': ['John Doe']},
#   {'task_name': 'About Us Page Development',
#    'estimated_time_hours': 40.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': 'Services Page Development',
#    'estimated_time_hours': 40.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': 'Contact Us Page Development',
#    'estimated_time_hours': 40.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': 'Blog Section Development',
#    'estimated_time_hours': 56.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': 'SEO Optimization',
#    'estimated_time_hours': 40.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': 'Social Media Integration',
#    'estimated_time_hours': 24.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': 'Testimonials Section Development',
#    'estimated_time_hours': 24.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': 'Quality Assurance Testing',
#    'estimated_time_hours': 56.0,
#    'required_resources': ['Alice Johnson', 'Tom Brown']},
#   {'task_name': 'Launch Website',
#    'estimated_time_hours': 16.0,
#    'required_resources': ['John Doe']},
#   {'task_name': 'Post Launch Support',
#    'estimated_time_hours': 112.0,
#    'required_resources': ['Entire Team']}],
#  'milestones': [{'milestone_name': 'Initial Setup and Design Phase',
#    'tasks': ['Project Kickoff',
#     'Research & Requirement Gathering',
#     'Wireframing',
#     'Mockup Design',
#     'Design Approval']},
#   {'milestone_name': 'Development Phase',
#    'tasks': ['Responsive Design Implementation',
#     'User Interface Development',
#     'Navigation System Development',
#     'Content Creation',
#     'About Us Page Development',
#     'Services Page Development',
#     'Contact Us Page Development',
#     'Blog Section Development',
#     'SEO Optimization',
#     'Social Media Integration',
#     'Testimonials Section Development']},
#   {'milestone_name': 'Testing and Launch Phase',
#    'tasks': ['Quality Assurance Testing', 'Launch Website']},
#   {'milestone_name': 'Support Phase', 'tasks': ['Post Launch Support']}]}

# %%
tasks = result.pydantic.dict()['tasks']
df_tasks = pd.DataFrame(tasks)

# Display the DataFrame as an HTML table
df_tasks.style.set_table_attributes('border="1"').set_caption("Task Details").set_table_styles(
    [{'selector': 'th, td', 'props': [('font-size', '120%')]}]
)
# Out:
# <style type="text/css">
# #T_7a469 th {
#   font-size: 120%;
# }
# #T_7a469  td {
#   font-size: 120%;
# }
# </style>
# <table id="T_7a469" border="1">
#   <caption>Task Details</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7a469_level0_col0" class="col_heading level0 col0" >task_name</th>
#       <th id="T_7a469_level0_col1" class="col_heading level0 col1" >estimated_time_hours</th>
#       <th id="T_7a469_level0_col2" class="col_heading level0 col2" >required_resources</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7a469_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7a469_row0_col0" class="data row0 col0" >Project Kickoff</td>
#       <td id="T_7a469_row0_col1" class="data row0 col1" >4.000000</td>
#       <td id="T_7a469_row0_col2" class="data row0 col2" >['John Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_7a469_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7a469_row1_col0" class="data row1 col0" >Research & Requirement Gathering</td>
#       <td id="T_7a469_row1_col1" class="data row1 col1" >20.000000</td>
#       <td id="T_7a469_row1_col2" class="data row1 col2" >['John Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_7a469_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7a469_row2_col0" class="data row2 col0" >Wireframing</td>
#       <td id="T_7a469_row2_col1" class="data row2 col1" >40.000000</td>
#       <td id="T_7a469_row2_col2" class="data row2 col2" >['Bob Smith']</td>
#     </tr>
#     <tr>
#       <th id="T_7a469_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7a469_row3_col0" class="data row3 col0" >Mockup Design</td>
#       <td id="T_7a469_row3_col1" class="data row3 col1" >40.000000</td>
#       <td id="T_7a469_row3_col2" class="data row3 col2" >['Bob Smith']</td>
#     </tr>
#     <tr>
#       <th id="T_7a469_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7a469_row4_col0" class="data row4 col0" >Design Approval</td>
#       <td id="T_7a469_row4_col1" class="data row4 col1" >20.000000</td>
#       <td id="T_7a469_row4_col2" class="data row4 col2" >['John Doe', 'Bob Smith']</td>
#     </tr>
#     <tr>
#       <th id="T_7a469_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_7a469_row5_col0" class="data row5 col0" >Responsive Design Implementation</td>
#       <td id="T_7a469_row5_col1" class="data row5 col1" >80.000000</td>
#       <td id="T_7a469_row5_col2" class="data row5 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_7a469_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_7a469_row6_col0" class="data row6 col0" >User Interface Development</td>
#       <td id="T_7a469_row6_col1" class="data row6 col1" >80.000000</td>
#       <td id="T_7a469_row6_col2" class="data row6 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_7a469_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_7a469_row7_col0" class="data row7 col0" >Navigation System Development</td>
#       <td id="T_7a469_row7_col1" class="data row7 col1" >40.000000</td>
#       <td id="T_7a469_row7_col2" class="data row7 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_7a469_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_7a469_row8_col0" class="data row8 col0" >Content Creation</td>
#       <td id="T_7a469_row8_col1" class="data row8 col1" >28.000000</td>
#       <td id="T_7a469_row8_col2" class="data row8 col2" >['John Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_7a469_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_7a469_row9_col0" class="data row9 col0" >About Us Page Development</td>
#       <td id="T_7a469_row9_col1" class="data row9 col1" >40.000000</td>
#       <td id="T_7a469_row9_col2" class="data row9 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_7a469_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_7a469_row10_col0" class="data row10 col0" >Services Page Development</td>
#       <td id="T_7a469_row10_col1" class="data row10 col1" >40.000000</td>
#       <td id="T_7a469_row10_col2" class="data row10 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_7a469_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_7a469_row11_col0" class="data row11 col0" >Contact Us Page Development</td>
#       <td id="T_7a469_row11_col1" class="data row11 col1" >40.000000</td>
#       <td id="T_7a469_row11_col2" class="data row11 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_7a469_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_7a469_row12_col0" class="data row12 col0" >Blog Section Development</td>
#       <td id="T_7a469_row12_col1" class="data row12 col1" >56.000000</td>
#       <td id="T_7a469_row12_col2" class="data row12 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_7a469_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_7a469_row13_col0" class="data row13 col0" >SEO Optimization</td>
#       <td id="T_7a469_row13_col1" class="data row13 col1" >40.000000</td>
#       <td id="T_7a469_row13_col2" class="data row13 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_7a469_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_7a469_row14_col0" class="data row14 col0" >Social Media Integration</td>
#       <td id="T_7a469_row14_col1" class="data row14 col1" >24.000000</td>
#       <td id="T_7a469_row14_col2" class="data row14 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_7a469_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_7a469_row15_col0" class="data row15 col0" >Testimonials Section Development</td>
#       <td id="T_7a469_row15_col1" class="data row15 col1" >24.000000</td>
#       <td id="T_7a469_row15_col2" class="data row15 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_7a469_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_7a469_row16_col0" class="data row16 col0" >Quality Assurance Testing</td>
#       <td id="T_7a469_row16_col1" class="data row16 col1" >56.000000</td>
#       <td id="T_7a469_row16_col2" class="data row16 col2" >['Alice Johnson', 'Tom Brown']</td>
#     </tr>
#     <tr>
#       <th id="T_7a469_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_7a469_row17_col0" class="data row17 col0" >Launch Website</td>
#       <td id="T_7a469_row17_col1" class="data row17 col1" >16.000000</td>
#       <td id="T_7a469_row17_col2" class="data row17 col2" >['John Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_7a469_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_7a469_row18_col0" class="data row18 col0" >Post Launch Support</td>
#       <td id="T_7a469_row18_col1" class="data row18 col1" >112.000000</td>
#       <td id="T_7a469_row18_col2" class="data row18 col2" >['Entire Team']</td>
#     </tr>
#   </tbody>
# </table>

# %%
milestones = result.pydantic.dict()['milestones']
df_milestones = pd.DataFrame(milestones)

# Display the DataFrame as an HTML table
df_milestones.style.set_table_attributes('border="1"').set_caption("Task Details").set_table_styles(
    [{'selector': 'th, td', 'props': [('font-size', '120%')]}]
)
# Out:
# <style type="text/css">
# #T_59116 th {
#   font-size: 120%;
# }
# #T_59116  td {
#   font-size: 120%;
# }
# </style>
# <table id="T_59116" border="1">
#   <caption>Task Details</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_59116_level0_col0" class="col_heading level0 col0" >milestone_name</th>
#       <th id="T_59116_level0_col1" class="col_heading level0 col1" >tasks</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_59116_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_59116_row0_col0" class="data row0 col0" >Initial Setup and Design Phase</td>
#       <td id="T_59116_row0_col1" class="data row0 col1" >['Project Kickoff', 'Research & Requirement Gathering', 'Wireframing', 'Mockup Design', 'Design Approval']</td>
#     </tr>
#     <tr>
#       <th id="T_59116_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_59116_row1_col0" class="data row1 col0" >Development Phase</td>
#       <td id="T_59116_row1_col1" class="data row1 col1" >['Responsive Design Implementation', 'User Interface Development', 'Navigation System Development', 'Content Creation', 'About Us Page Development', 'Services Page Development', 'Contact Us Page Development', 'Blog Section Development', 'SEO Optimization', 'Social Media Integration', 'Testimonials Section Development']</td>
#     </tr>
#     <tr>
#       <th id="T_59116_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_59116_row2_col0" class="data row2 col0" >Testing and Launch Phase</td>
#       <td id="T_59116_row2_col1" class="data row2 col1" >['Quality Assurance Testing', 'Launch Website']</td>
#     </tr>
#     <tr>
#       <th id="T_59116_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_59116_row3_col0" class="data row3 col0" >Support Phase</td>
#       <td id="T_59116_row3_col1" class="data row3 col1" >['Post Launch Support']</td>
#     </tr>
#   </tbody>
# </table>
